# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Modelos-de-regresión" data-toc-modified-id="Modelos-de-regresión-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Modelos de regresión</a></span><ul class="toc-item"><li><span><a href="#Puntuación-de-varianza-explicada" data-toc-modified-id="Puntuación-de-varianza-explicada-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Puntuación de varianza explicada</a></span></li><li><span><a href="#Error-máximo" data-toc-modified-id="Error-máximo-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Error máximo</a></span></li><li><span><a href="#Error-absoluto-medio-(MAE)" data-toc-modified-id="Error-absoluto-medio-(MAE)-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Error absoluto medio (MAE)</a></span></li><li><span><a href="#Error-cuadrático-medio-(MSE)" data-toc-modified-id="Error-cuadrático-medio-(MSE)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Error cuadrático medio (MSE)</a></span></li><li><span><a href="#Raíz-del-error-cuadrático-medio-(RMSE)" data-toc-modified-id="Raíz-del-error-cuadrático-medio-(RMSE)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Raíz del error cuadrático medio (RMSE)</a></span></li><li><span><a href="#Error-logarítmico-cuadrático-medio-(MSLE)" data-toc-modified-id="Error-logarítmico-cuadrático-medio-(MSLE)-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Error logarítmico cuadrático medio (MSLE)</a></span></li><li><span><a href="#Error-absoluto-mediano-(MedAE)" data-toc-modified-id="Error-absoluto-mediano-(MedAE)-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Error absoluto mediano (MedAE)</a></span></li><li><span><a href="#Coeficiente-de-determinación,-R-cuadrado" data-toc-modified-id="Coeficiente-de-determinación,-R-cuadrado-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Coeficiente de determinación, R cuadrado</a></span></li><li><span><a href="#Otras-métricas" data-toc-modified-id="Otras-métricas-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Otras métricas</a></span></li></ul></li><li><span><a href="#Modelos-de-clasificación" data-toc-modified-id="Modelos-de-clasificación-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Modelos de clasificación</a></span><ul class="toc-item"><li><span><a href="#Exactitud-(accuracy)" data-toc-modified-id="Exactitud-(accuracy)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Exactitud (accuracy)</a></span></li><li><span><a href="#Precisión-(precision)" data-toc-modified-id="Precisión-(precision)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Precisión (precision)</a></span></li><li><span><a href="#Recuperación-(recall)" data-toc-modified-id="Recuperación-(recall)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Recuperación (recall)</a></span></li><li><span><a href="#Precisión-promedio-(average-precision)" data-toc-modified-id="Precisión-promedio-(average-precision)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Precisión promedio (average precision)</a></span></li><li><span><a href="#Puntuación-F1" data-toc-modified-id="Puntuación-F1-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Puntuación F1</a></span></li><li><span><a href="#Pérdida-logarítmica-(log-loss)" data-toc-modified-id="Pérdida-logarítmica-(log-loss)-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Pérdida logarítmica (log loss)</a></span></li></ul></li><li><span><a href="#Modelos-de-agrupamiento" data-toc-modified-id="Modelos-de-agrupamiento-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modelos de agrupamiento</a></span><ul class="toc-item"><li><span><a href="#Mutual-info-score" data-toc-modified-id="Mutual-info-score-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Mutual info score</a></span></li><li><span><a href="#Adjusted-mutual-info-score" data-toc-modified-id="Adjusted-mutual-info-score-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Adjusted mutual info score</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Modelos de regresión

# %% [markdown]
# ## Puntuación de varianza explicada

# %% [markdown]
# La varianza explicada (explained variance score) mide la proporción en la que un modelo matemático explica la variación (dispersión) de un conjunto de datos. La parte complementaria de la variación total se denomina variación residual o inexplicable.

# %% [markdown]
# ![varianza_explicada.JPG](attachment:varianza_explicada.JPG)

# %% [markdown]
# El resultado ideal de esta métrica es 1.0 (cuanto más pequeño, peor).

# %%
from sklearn.metrics import explained_variance_score
import numpy as np

# %%
y_true = np.array([3, -0.5, 2, 7])
y_pred = np.array([2.5, 0.0, 2, 8])

# %%
explained_variance_score(y_true, y_pred)
# Out:
# 0.9571734475374732

# %%
1 - (np.var(y_true-y_pred)/np.var(y_true))
# Out:
# 0.9571734475374732

# %% [markdown]
# ## Error máximo

# %% [markdown]
# La métrica de error máximo (max error) calcula el error residual máximo, es decir, el máximo error que se ha obtenido entre un valor real y una predicción.

# %% [markdown]
# ![max_error.JPG](attachment:max_error.JPG)

# %% [markdown]
# El valor ideal es 0.

# %%
from sklearn.metrics import max_error

# %%
y_true = [3, 2, 7, 1]
y_pred = [4, 2, 7, 1]

# %%
max_error(y_true, y_pred)
# Out:
# 1

# %% [markdown]
# ## Error absoluto medio (MAE)

# %% [markdown]
# El error absoluto medio (mean absolute error) es una medida de la diferencia entre dos variables continuas y se utiliza para cuantificar la precisión de una técnica de predicción comparando los valores predichos con los reales (observados).

# %% [markdown]
# ![mae.JPG](attachment:mae.JPG)

# %% [markdown]
# Cuanto más pequeño, mejor.

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_true = np.array([3, -0.5, 2, 7])
y_pred = np.array([2.5, 0.0, 2, 8])

# %%
mean_absolute_error(y_true, y_pred)
# Out:
# 0.5

# %%
sum(abs(y_true-y_pred))/len(y_true)
# Out:
# 0.5

# %% [markdown]
# ## Error cuadrático medio (MSE)

# %% [markdown]
# El error cuadrático medio (mean squared error) mide el promedio de los errores al cuadrado, es decir, la diferencia entre el estimador y lo que se estima.

# %% [markdown]
# ![mse.JPG](attachment:mse.JPG)

# %% [markdown]
# Cuanto más pequeño, mejor.

# %%
from sklearn.metrics import mean_squared_error

# %%
y_true
# Out:
# array([ 3. , -0.5,  2. ,  7. ])

# %%
y_pred
# Out:
# array([2.5, 0. , 2. , 8. ])

# %%
mean_squared_error(y_true, y_pred)
# Out:
# 0.375

# %%
(sum((y_true - y_pred)**2))/len(y_true)
# Out:
# 0.375

# %% [markdown]
# ## Raíz del error cuadrático medio (RMSE)

# %% [markdown]
# La raíz del error cuadrático medio (root-mean-square error) o raíz de la desviación cuadrática media (root-mean-square deviation, RMSD) también es una medida de la diferencia entre el estimador y lo que se estima.

# %% [markdown]
# Cuanto más pequeño, mejor.

# %%
mean_squared_error(y_true, y_pred, squared = False)
# Out:
# 0.6123724356957945

# %% [markdown]
# ## Error logarítmico cuadrático medio (MSLE)

# %% [markdown]
# Es simplemente un RMSE calculado en escala logarítmica. Esta métrica es más apropiada para casos en que la variable objetivo  tiene un crecimiento exponencial, como el recuento de la población, las ventas promedio de un producto durante un periodo de años, etc.

# %% [markdown]
# ![msle.JPG](attachment:msle.JPG)

# %% [markdown]
# Cuanto más pequeño, mejor.

# %%
from sklearn.metrics import mean_squared_log_error

# %%
y_true = [3, 5, 2.5, 7]
y_pred = [2.5, 5, 4, 8]

# %%
mean_squared_log_error(y_true, y_pred)
# Out:
# 0.03973012298459379

# %% [markdown]
# ## Error absoluto mediano (MedAE)

# %% [markdown]
# Esta métrica es particularmente interesante porque es robusta a los valores atípicos. Se calcula tomando la mediana de todas las diferencias absolutas entre la variable objetivo y la predicción.

# %% [markdown]
# ![medae.JPG](attachment:medae.JPG)

# %% [markdown]
# Cuanto más pequeño, mejor.

# %%
from sklearn.metrics import median_absolute_error

# %%
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
median_absolute_error(y_true, y_pred)
# Out:
# 0.5

# %% [markdown]
# ## Coeficiente de determinación, R cuadrado

# %% [markdown]
# Representa la proporción de varianza de la variable objetivo que ha sido explicada por las variables independientes en el modelo. Proporciona una indicación de bondad de ajuste y, por lo tanto, de cómo de bien es probable que el modelo vaya a predecir nuevas muestras, a través de la proporción de varianza explicada.
#
# Esta métrica se verá más en profundidad en la sección de modelos de regresión, más adelante.

# %% [markdown]
# ## Otras métricas

# %% [markdown]
# Existen otras métricas apropiadas para evaluar el rendimiento de regresión, que no se tratarán aquí.

# %% [markdown]
# # Modelos de clasificación

# %% [markdown]
# ## Exactitud (accuracy)

# %% [markdown]
# Calcula la exactitud, ya sea mediante la fracción o el recuento de predicciones correctas.

# %% [markdown]
# ![accuracy.JPG](attachment:accuracy.JPG)

# %% [markdown]
# El mejor valor es un 1 (todo el conjunto de etiquetas predichas para una muestra coincide estrictamente con el conjunto real de etiquetas) y el peor, un 0.

# %%
from sklearn.metrics import accuracy_score

# %%
y_true = [0, 1, 2, 3]
y_pred = [0, 2, 1, 3]

# %%
accuracy_score(y_true, y_pred, normalize=True)
# Out:
# 0.5

# %%
accuracy_score(y_true, y_pred, normalize=False)
# Out:
# 2

# %% [markdown]
# ## Precisión (precision)

# %% [markdown]
# La precisión es el ratio tp / (tp + fp), donde tp es el número de verdaderos positivos y fp el número de falsos positivos. La precisión nos da una idea de la capacidad del modelo clasificador de no etiquetar como positiva una muestra que realmente es negativa.

# %% [markdown]
# ![precision2.JPG](attachment:precision2.JPG)

# %% [markdown]
# El mejor valor es un 1 y el peor, un 0.

# %%
from sklearn.metrics import precision_score
y_true = [0, 1, 2, 0, 1, 2]
y_pred = [0, 2, 1, 0, 0, 1]

# %%
precision_score(y_true, y_pred, average=None)
# Out:
# array([0.66666667, 0.        , 0.        ])

# %% [markdown]
# Para la clase 0:
# - TP: I I
# - Fp: I
# P(clase_0) = 2/(2+1) = 0.66666667
#
# Para la clase 1:
# - Tp: 0
# - Fp: I I
# P(clase_1) = 0/(0+2) = 0
#
# Para la clase 2:
# - Tp: 0
# - Fp: I
# P(clase_2) = 0/(0+1) = 0

# %% [markdown]
# ## Recuperación (recall)

# %% [markdown]
# El recall es el ratio tp / (tp + fn), donde tp es el número de verdaderos positivos y fn el número de falsos negativos. Nos permite hacernos una idea de la capacidad del modelo clasificador de encontrar todas las muestras positivas.

# %% [markdown]
# ![recall2.JPG](attachment:recall2.JPG)

# %% [markdown]
# El mejor valor es un 1 y el peor, un 0.

# %%
from sklearn.metrics import recall_score

# %%
y_true = [0, 1, 2, 0, 1, 2]
y_pred = [0, 2, 1, 0, 0, 1]

# %%
recall_score(y_true, y_pred, average=None)
# Out:
# array([1., 0., 0.])

# %% [markdown]
# Para la clase 0:
# - Tp: I I
# - Fn: 0
# R(clase_0) = 2/(2+0) = 1

# %% [markdown]
# ## Precisión promedio (average precision)

# %% [markdown]
# Calcula la precisión promedio (AP) a partir de las predicciones. Básicamente, resume una curva precision-recall (que veremos más adelante) como la media ponderada de las precisiones logradas en cada umbral, con el aumento en el recall del umbral anterior utilizado como ponderación.

# %% [markdown]
# ![average_precision.JPG](attachment:average_precision.JPG)

# %% [markdown]
# ## Puntuación F1

# %% [markdown]
# La puntuación F1 se define como la media armónica de la precisión y el recall, y se puede interpretar como un promedio ponderado de ambos. La contribución relativa de precisión y recall a la puntuación F1 es la misma.

# %% [markdown]
# ![f1score2.JPG](attachment:f1score2.JPG)

# %% [markdown]
# Una puntuación F1 alcanza su mejor valor en 1 y la peor puntuación en 0.

# %%
from sklearn.metrics import f1_score

# %%
y_true = [0, 1, 2, 0, 1, 2]
y_pred = [0, 2, 1, 0, 0, 1]

# %%
f1_score(y_true, y_pred, average=None)
# Out:
# array([0.8, 0. , 0. ])

# %%
f1_score_0 = 2*(0.66666667*1.)/(0.66666667+1.)
f1_score_0
# Out:
# 0.8000000023999999

# %% [markdown]
# ## Pérdida logarítmica (log loss)

# %% [markdown]
# La pérdida logarítmica, también conocida como pérdida de regresión logística o pérdida de entropía cruzada, es la función de pérdida utilizada en la regresión logística (multinomial) y sus extensiones, como las redes neuronales, y se considera la métrica de clasificación basada en probabilidades más importante.
#
# La log loss se basa en una función de probabilidad. De hecho, Log Loss es -1 * el logaritmo de la función de probabilidad, la cual responde a la pregunta "¿cómo de probable pensó el modelo que era el conjunto de resultados realmente observado?".
#
# Cuanto más pequeña, mejor.

# %% [markdown]
# # Modelos de agrupamiento

# %% [markdown]
# ## Mutual info score

# %% [markdown]
# La información mutua (MI) es una medida de la similitud entre dos etiquetas de los mismos datos. Donde |Ui| es el número de muestras en el cluster Ui y |Vj| es el número de muestras en el cluster Vj, la Información Mutua (Mutual Information) entre los clusters U y V viene dada como:

# %% [markdown]
# ![mutual_info.JPG](attachment:mutual_info.JPG)

# %% [markdown]
# ## Adjusted mutual info score

# %% [markdown]
# Indica la información mutua ajustada entre dos agrupaciones. La información mutua ajustada (AMI) es un ajuste de la Mutual Information (MI) para tener en cuenta el azar. Explica el hecho de que MI es generalmente más alta para dos agrupaciones con una mayor cantidad de agrupaciones, independientemente de si en realidad se comparte más información. Para dos agrupaciones y , el AMI se da como:
