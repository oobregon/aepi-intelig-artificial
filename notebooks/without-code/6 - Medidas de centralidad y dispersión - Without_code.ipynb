# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Librerías-de-estadística-en-Python" data-toc-modified-id="Librerías-de-estadística-en-Python-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Librerías de estadística en Python</a></span></li><li><span><a href="#Medidas-de-promedio-y-ubicación-central" data-toc-modified-id="Medidas-de-promedio-y-ubicación-central-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Medidas de promedio y ubicación central</a></span><ul class="toc-item"><li><span><a href="#Media-aritmética" data-toc-modified-id="Media-aritmética-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Media aritmética</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-numpy" data-toc-modified-id="Cálculo-con-numpy-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>Cálculo con numpy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-2.1.2.4"><span class="toc-item-num">2.1.2.4&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li><li><span><a href="#Media-geométrica" data-toc-modified-id="Media-geométrica-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Media geométrica</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-2.2.2.2"><span class="toc-item-num">2.2.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-numpy" data-toc-modified-id="Cálculo-con-numpy-2.2.2.3"><span class="toc-item-num">2.2.2.3&nbsp;&nbsp;</span>Cálculo con numpy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-2.2.2.4"><span class="toc-item-num">2.2.2.4&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li><li><span><a href="#Media-armónica" data-toc-modified-id="Media-armónica-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Media armónica</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-2.3.2.1"><span class="toc-item-num">2.3.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-2.3.2.2"><span class="toc-item-num">2.3.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-numpy" data-toc-modified-id="Cálculo-con-numpy-2.3.2.3"><span class="toc-item-num">2.3.2.3&nbsp;&nbsp;</span>Cálculo con numpy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-2.3.2.4"><span class="toc-item-num">2.3.2.4&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li><li><span><a href="#Mediana" data-toc-modified-id="Mediana-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Mediana</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-2.4.2.1"><span class="toc-item-num">2.4.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-2.4.2.2"><span class="toc-item-num">2.4.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-numpy" data-toc-modified-id="Cálculo-con-numpy-2.4.2.3"><span class="toc-item-num">2.4.2.3&nbsp;&nbsp;</span>Cálculo con numpy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-2.4.2.4"><span class="toc-item-num">2.4.2.4&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li><li><span><a href="#Moda" data-toc-modified-id="Moda-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Moda</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-2.5.2.1"><span class="toc-item-num">2.5.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-2.5.2.2"><span class="toc-item-num">2.5.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-numpy" data-toc-modified-id="Cálculo-con-numpy-2.5.2.3"><span class="toc-item-num">2.5.2.3&nbsp;&nbsp;</span>Cálculo con numpy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-2.5.2.4"><span class="toc-item-num">2.5.2.4&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Medidas-de-variabilidad" data-toc-modified-id="Medidas-de-variabilidad-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Medidas de variabilidad</a></span><ul class="toc-item"><li><span><a href="#Varianza" data-toc-modified-id="Varianza-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Varianza</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-3.1.2.1"><span class="toc-item-num">3.1.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-3.1.2.2"><span class="toc-item-num">3.1.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-3.1.2.3"><span class="toc-item-num">3.1.2.3&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li><li><span><a href="#Desviación-típica" data-toc-modified-id="Desviación-típica-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Desviación típica</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Ejemplos" data-toc-modified-id="Ejemplos-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Ejemplos</a></span><ul class="toc-item"><li><span><a href="#Cálculo-con-statistics" data-toc-modified-id="Cálculo-con-statistics-3.2.2.1"><span class="toc-item-num">3.2.2.1&nbsp;&nbsp;</span>Cálculo con statistics</a></span></li><li><span><a href="#Cálculo-con-scipy" data-toc-modified-id="Cálculo-con-scipy-3.2.2.2"><span class="toc-item-num">3.2.2.2&nbsp;&nbsp;</span>Cálculo con scipy</a></span></li><li><span><a href="#Cálculo-con-pandas" data-toc-modified-id="Cálculo-con-pandas-3.2.2.3"><span class="toc-item-num">3.2.2.3&nbsp;&nbsp;</span>Cálculo con pandas</a></span></li></ul></li></ul></li><li><span><a href="#Covarianza" data-toc-modified-id="Covarianza-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Covarianza</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Concepto</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Librerías de estadística en Python

# %% [markdown]
# En Python, hay varias librerías con módulos de estadística. A continuación, enumeramos algunas de ellas:
# - La librería estándar de Python incluye el módulo **statistics**. Tal y como se indica en la documentación oficial, este módulo no pretende ser competencia de otras bibliotecas de terceros, como NumPy o SciPy, sino que está más enfocado en gráficas y en servir como calculadora científica.
# - **NumPy** proporciona varias funciones que permiten aplicar cálculos estadísticos.
# - **SciPy** tiene el módulo **stats**, que incluye un gran número de funciones estadísticas.
# - **pandas**, como NumPy, también cuenta con funciones para realizar cálculos estadísticos.

# %% [markdown]
# En primer lugar, vamos a crear unos datos con los cuales podamos trabajar. A continuación, iremos revisando los conceptos fundamentales de estadística y, a su vez, veremos ejemplos aplicados a conjuntos de datos, utilizando para ello el módulo *statistics* de la librería estándar de Python, el módulo *stats* de *SciPy* y las funciones de *pandas*.

# %% [markdown]
# # Medidas de promedio y ubicación central

# %% [markdown]
# Nos permiten comprender cuáles son los valores centrales del conjunto de datos, calculando un promedio o valor típico.

# %% [markdown]
# ## Media aritmética

# %% [markdown]
# ### Concepto

# %% [markdown]
# La media aritmética es la suma de todos los datos dividida por el número de datos. Comúnmente, se conoce como "promedio", aunque hay muchos promedios matemáticos distintos.

# %% [markdown]
# ![1_media_aritmetica.JPG](attachment:1_media_aritmetica.JPG)

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %% [markdown]
# #### Cálculo con scipy

# %% [markdown]
# #### Cálculo con numpy

# %% [markdown]
# #### Cálculo con pandas

# %% [markdown]
# ## Media geométrica

# %% [markdown]
# ### Concepto

# %% [markdown]
# La media geométrica da información acerca de la tendencia central o el valor típico de los datos, pero utiliza el producto de los valores, a diferencia de la media aritmética que usa la suma. Para un conjunto de n datos, se calcula como la raíz n-ésima del producto de todos los datos:

# %% [markdown]
# ![3_media_geometrica.JPG](attachment:3_media_geometrica.JPG)

# %% [markdown]
# Se utiliza especialmente para promediar porcentajes.

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %% [markdown]
# #### Cálculo con scipy

# %% [markdown]
# #### Cálculo con numpy

# %%
# No tiene esta función

# %% [markdown]
# #### Cálculo con pandas

# %%
# No tiene esta función

# %% [markdown]
# ## Media armónica

# %% [markdown]
# ### Concepto

# %% [markdown]
# La media armónica de un conjunto de valores es el inverso de la media aritmética de los inversos de dichos valores:

# %% [markdown]
# ![2_media_armonica.JPG](attachment:2_media_armonica.JPG)

# %% [markdown]
# Se utiliza a menudo para promediar velocidades y tiempos.

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %% [markdown]
# #### Cálculo con scipy

# %% [markdown]
# #### Cálculo con numpy

# %%
# No tiene esta función

# %% [markdown]
# #### Cálculo con pandas

# %%
# No tiene esta función

# %% [markdown]
# ## Mediana

# %% [markdown]
# ### Concepto

# %% [markdown]
# La mediana es el valor que divide el conjunto de datos en dos partes con el mismo número de valores. Si se ordenan todos los datos de menor a mayor:
# - En el caso de que el conjunto tenga un número impar de valores, la mediana es el dato que está justo "en el medio", dejando tantos datos por debajo como por encima de su valor.
# - En el caso de que el conjunto tenga un número par de valores, la mediana es la media aritmética de los dos datos centrales.

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %% [markdown]
# #### Cálculo con scipy

# %% [markdown]
# #### Cálculo con numpy

# %% [markdown]
# #### Cálculo con pandas

# %% [markdown]
# ## Moda

# %% [markdown]
# ### Concepto

# %% [markdown]
# La moda es el valor que más veces se repite en el conjunto de datos, es decir, el valor más frecuente.

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %% [markdown]
# En versiones antiguas, si no encuentra una única moda, devuelve un error. En versiones nuevas, devuelve la primera moda que encuentra.

# %% [markdown]
# Para obtener una lista con todos los valores más frecuentes, hay que utilizar la función *multimode*. Por ejemplo:

# %% [markdown]
# #### Cálculo con scipy

# %% [markdown]
# Si hay más de una moda, devuelve solo la que tenga valor más pequeño.

# %% [markdown]
# #### Cálculo con numpy

# %%
# ---

# %% [markdown]
# #### Cálculo con pandas

# %% [markdown]
# Si hay más de una moda, las devuelve todas.

# %% [markdown]
# # Medidas de variabilidad

# %% [markdown]
# Nos dan información acerca de la dispersión que presentan los datos, es decir, permiten calcular una medida de cuánto tienden a desviarse los datos con respecto a los valores típicos o promedio.

# %% [markdown]
# ## Varianza

# %% [markdown]
# ### Concepto

# %% [markdown]
# La varianza es una medida de variabilidad que indica la dispersión de un conjunto de datos con respecto a su media.

# %% [markdown]
# ![muestravspoblacion.png](attachment:muestravspoblacion.png)

# %% [markdown]
# Varianza muestral:

# %% [markdown]
# ![varianza_muestral.JPG](attachment:varianza_muestral.JPG)

# %% [markdown]
# Varianza poblacional:

# %% [markdown]
# ![varianza_poblacional.JPG](attachment:varianza_poblacional.JPG)

# %%
# Varianza muestral

# %%
# Varianza poblacional

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %%
# Varianza muestral

# %%
# Varianza poblacional

# %% [markdown]
# #### Cálculo con scipy

# %%
# Muestral (1 grado de libertad)

# %%
# Varianza poblacional (0 grados de libertad)

# %% [markdown]
# #### Cálculo con pandas

# %%
# Muestral (1 grado de libertad)

# %%
# Varianza poblacional (0 grados de libertad)

# %% [markdown]
# ## Desviación típica

# %% [markdown]
# ### Concepto

# %% [markdown]
# La desviación estándar o desviación típica es la medida de dispersión más común e indica cómo de dispersos se encuentran los datos con respecto a la media. Cuando mayor sea la desviación estándar, mayor será la dispersión de los datos.
#
# Básicamente, es la raíz cuadrada de la varianza, por lo que las unidades serán las mismas que las de los datos de origen.

# %% [markdown]
# Desviación típica muestral:

# %% [markdown]
# ![desv_muestral.JPG](attachment:desv_muestral.JPG)

# %% [markdown]
# Desviación típica poblacional:

# %% [markdown]
# ![desv_poblacional.JPG](attachment:desv_poblacional.JPG)

# %%
# Varianza muestral

# %%
# Varianza poblacional

# %%
# Desviación típica muestral

# %%
# Desviación típica poblacional

# %% [markdown]
# ### Ejemplos

# %% [markdown]
# #### Cálculo con statistics

# %%
# Desviación estándar muestral

# %%
# Desviación estándar poblacional

# %% [markdown]
# #### Cálculo con scipy

# %%
# Desviación estándar muestral

# %%
# Desviación estándar poblacional

# %%
# Desviación estándar poblacional sin recortar

# %%
# Desviación estándar poblacional recortada

# %% [markdown]
# #### Cálculo con pandas

# %%
# Desviación estándar muestral

# %%
# Desviación estándar poblacional

# %%
# Desviación estándar muestral

# %% [markdown]
# ## Covarianza

# %% [markdown]
# ### Concepto

# %% [markdown]
# **¡Importante! La covarianza está tratada en profundidad en otro notebook.**

# %% [markdown]
# La covarianza es una medida que indica en qué grado dos variables aleatorias varían de forma conjunta respecto a sus medias. Se puede calcular mediante la siguiente fórmula:

# %% [markdown]
# ![cov.jpg](attachment:cov.jpg)

# %% [markdown]
# En esencia, nos permite conocer de qué manera evoluciona una variable en función de lo que hace otra variable, pudiendo tomar los siguiente valores:
#
# - Covarianza(X,Y)=0: no hay relación entre las variables X e Y.
#
# - Covarianza(X,Y)<0: cuando X aumenta, Y disminuye. Hay una relación negativa.
#
# - Covarianza(X,Y)>0: cuando X aumenta, Y aumenta. Hay una relación positiva.

# %% [markdown]
# La covarianza tiene las siguientes propiedades:
# - Cov(X,b)=0, donde b es una constante.
# - Cov(X,X)=Var(X)
# - Cov(X,Y)=Cov(Y,X)
# - Cov(b·X,c·Y)=c·b·Cov(X,Y)
# - Cov(b+X,c+Y)=Cov(X,Y)

# %% [markdown]
# Es importante tener en cuenta que las covarianzas de distintas variables no son comparables, puesto que el valor de la covarianza es un valor absoluto que depende de la unidad de medida de las variables.
